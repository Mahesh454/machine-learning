# %%
import pandas as pd
import numpy as np

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
data=requests.get("https://www.indiabudget.gov.in")

# %%
content=data.content
content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n  <head>\r\n    <title>Union Budget</title>\r\n    <meta charset="utf-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\r\n    <link href="css/quicksand.css" rel="stylesheet">\r\n    <link rel="stylesheet" href="fonts/icomoon/style.css">\r\n    <link rel="stylesheet" href="css/bootstrap.min.css">\r\n    <link rel="stylesheet" href="css/carousel.css">\r\n    <link rel="stylesheet" href="css/magnific-popup.css">\r\n    <link rel="stylesheet" href="css/jquery-ui.css">\r\n    <link rel="stylesheet" href="css/owl.carousel.min.css">\r\n    <link rel="stylesheet" href="css/owl.theme.default.min.css">\r\n    <link rel="stylesheet" href="css/bootstrap-datepicker.css">\r\n    <link rel="stylesheet" href="fonts/flaticon/font/flaticon.css">\r\n    <link rel="stylesheet" href="css/aos.css"> \r\n    <link rel="stylesheet" href="css/baguetteBox.min.css"> \r\n  \r\n \r\n    \r\n  </head>\r\n  <body>\r\n  <link r
# ...

# %%
data.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(data.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Union Budget</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link href="css/quicksand.css" rel="stylesheet"/>
# <link href="fonts/icomoon/style.css" rel="stylesheet"/>
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/carousel.css" rel="stylesheet"/>
# <link href="css/magnific-popup.css" rel="stylesheet"/>
# <link href="css/jquery-ui.css" rel="stylesheet"/>
# <link href="css/owl.carousel.min.css" rel="stylesheet"/>
# <link href="css/owl.theme.default.min.css" rel="stylesheet"/>
# <link href="css/bootstrap-datepicker.css" rel="stylesheet"/>
# <link href="fonts/flaticon/font/flaticon.css" rel="stylesheet"/>
# <link href="css/aos.css" rel="stylesheet"/>
# <link href="css/baguetteBox.min.css" rel="stylesheet"/>
# </head>
# <body>
# <link href="css/style.css" id="dark" rel="stylesheet"/>
# <style>
#   html {
#   font-size: 16px;
# }
#
# ...

# %%
soup.children

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <title>\n   Union Budget\n  </title>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>\n  <link href="css/quicksand.css" rel="stylesheet"/>\n  <link href="fonts/icomoon/style.css" rel="stylesheet"/>\n  <link href="css/bootstrap.min.css" rel="stylesheet"/>\n  <link href="css/carousel.css" rel="stylesheet"/>\n  <link href="css/magnific-popup.css" rel="stylesheet"/>\n  <link href="css/jquery-ui.css" rel="stylesheet"/>\n  <link href="css/owl.carousel.min.css" rel="stylesheet"/>\n  <link href="css/owl.theme.default.min.css" rel="stylesheet"/>\n  <link href="css/bootstrap-datepicker.css" rel="stylesheet"/>\n  <link href="fonts/flaticon/font/flaticon.css" rel="stylesheet"/>\n  <link href="css/aos.css" rel="stylesheet"/>\n  <link href="css/baguetteBox.min.css" rel="stylesheet"/>\n </head>\n <body>\n  <link href="css/style.css" id="dark" rel="stylesheet"/>\n  <style>\n   html {\r
# ...

# %%
soup.children

# %%
list(soup.children)
# Out:
# ['html', <html lang="en">
#  <head>
#  <title>Union Budget</title>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#  <link href="css/quicksand.css" rel="stylesheet"/>
#  <link href="fonts/icomoon/style.css" rel="stylesheet"/>
#  <link href="css/bootstrap.min.css" rel="stylesheet"/>
#  <link href="css/carousel.css" rel="stylesheet"/>
#  <link href="css/magnific-popup.css" rel="stylesheet"/>
#  <link href="css/jquery-ui.css" rel="stylesheet"/>
#  <link href="css/owl.carousel.min.css" rel="stylesheet"/>
#  <link href="css/owl.theme.default.min.css" rel="stylesheet"/>
#  <link href="css/bootstrap-datepicker.css" rel="stylesheet"/>
#  <link href="fonts/flaticon/font/flaticon.css" rel="stylesheet"/>
#  <link href="css/aos.css" rel="stylesheet"/>
#  <link href="css/baguetteBox.min.css" rel="stylesheet"/>
#  </head>
#  <body>
#  <link href="css/style.css" id="dark" rel="stylesheet"/>
#  <style>
#    html {
# ...

# %%
BeautifulSoup(content,"html.parser")#,"html.parser" defult inbult
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Union Budget</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link href="css/quicksand.css" rel="stylesheet"/>
# <link href="fonts/icomoon/style.css" rel="stylesheet"/>
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/carousel.css" rel="stylesheet"/>
# <link href="css/magnific-popup.css" rel="stylesheet"/>
# <link href="css/jquery-ui.css" rel="stylesheet"/>
# <link href="css/owl.carousel.min.css" rel="stylesheet"/>
# <link href="css/owl.theme.default.min.css" rel="stylesheet"/>
# <link href="css/bootstrap-datepicker.css" rel="stylesheet"/>
# <link href="fonts/flaticon/font/flaticon.css" rel="stylesheet"/>
# <link href="css/aos.css" rel="stylesheet"/>
# <link href="css/baguetteBox.min.css" rel="stylesheet"/>
# </head>
# <body>
# <link href="css/style.css" id="dark" rel="stylesheet"/>
# <style>
#   html {
#   font-size: 16px;
# }
# ...

# %%
clas=soup.find("div",{"class":"site-wrap"})
clas
# Out:
# <div class="site-wrap">
# <div class="site-mobile-menu">
# <div class="site-mobile-menu-header">
# <div class="site-mobile-menu-close mt-3">
# <span class="icon-close2 js-menu-toggle"></span>
# </div>
# </div>
# <div class="site-mobile-menu-body"></div>
# </div>
# <div class="border-bottom top-bar">
# <div class="container">
# <div class="row">
# <div class="common-left clearfix">
# <ul>
# <li class="gov-india">
# <span class="responsive_go_hindi" lang="hi">
# <a href="https://india.gov.in/hi/" role="link" target="_BLANK" title="Government of India">भारत सरकार</a>
# </span>
# <span class="li_eng responsive_go_eng">
# <a href="https://india.gov.in/" role="link" target="_BLANK" title="Government of India">GOVERNMENT OF INDIA</a>
# </span>
# </li>
# <li class="ministry">
# <span class="responsive_minis_hi" lang="hi">
# <a href="https://finmin.nic.in/hi/" role="link" title="Ministry of Finance">वित्त मंत्रालय</a>
# </span>
# <span class="li_eng responsive_minis_eng">
# ...

# %%
clas.find_all()
# Out:
# [<div class="site-mobile-menu">
#  <div class="site-mobile-menu-header">
#  <div class="site-mobile-menu-close mt-3">
#  <span class="icon-close2 js-menu-toggle"></span>
#  </div>
#  </div>
#  <div class="site-mobile-menu-body"></div>
#  </div>, <div class="site-mobile-menu-header">
#  <div class="site-mobile-menu-close mt-3">
#  <span class="icon-close2 js-menu-toggle"></span>
#  </div>
#  </div>, <div class="site-mobile-menu-close mt-3">
#  <span class="icon-close2 js-menu-toggle"></span>
#  </div>, <span class="icon-close2 js-menu-toggle"></span>, <div class="site-mobile-menu-body"></div>, <div class="border-bottom top-bar">
#  <div class="container">
#  <div class="row">
#  <div class="common-left clearfix">
#  <ul>
#  <li class="gov-india">
#  <span class="responsive_go_hindi" lang="hi">
#  <a href="https://india.gov.in/hi/" role="link" target="_BLANK" title="Government of India">भारत सरकार</a>
#  </span>
#  <span class="li_eng responsive_go_eng">
# ...
