# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("atlantictrain.csv")

# %%
df.head()
# Out:
#          ID                 Name      Date  Time Event Status Latitude  \
# 0  AL011851              UNNAMED  18510625     0           HU    28.0N
# 1  AL011851              UNNAMED  18510625   600           HU    28.0N
# 2  AL011851              UNNAMED  18510625  1200           HU    28.0N
# 3  AL011851              UNNAMED  18510625  1800           HU    28.1N
# 4  AL011851              UNNAMED  18510625  2100     L     HU    28.2N
#
#   Longitude  Maximum Wind  Minimum Pressure  ...  Low Wind SW  Low Wind NW  \
# 0     94.8W            80              -999  ...         -999         -999
# 1     95.4W            80              -999  ...         -999         -999
# 2     96.0W            80              -999  ...         -999         -999
# 3     96.5W            80              -999  ...         -999         -999
# 4     96.8W            80              -999  ...         -999         -999
#
#    Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Date', 'Time', 'Event', 'Status', 'Latitude',
#        'Longitude', 'Maximum Wind', 'Minimum Pressure', 'Low Wind NE',
#        'Low Wind SE', 'Low Wind SW', 'Low Wind NW', 'Moderate Wind NE',
#        'Moderate Wind SE', 'Moderate Wind SW', 'Moderate Wind NW',
#        'High Wind NE', 'High Wind SE', 'High Wind SW', 'High Wind NW'],
#       dtype='object')

# %%
xtrain=df[[c for c in df if c not in ["Status"]]]
xtrain.columns
# Out:
# Index(['ID', 'Name', 'Date', 'Time', 'Event', 'Latitude', 'Longitude',
#        'Maximum Wind', 'Minimum Pressure', 'Low Wind NE', 'Low Wind SE',
#        'Low Wind SW', 'Low Wind NW', 'Moderate Wind NE', 'Moderate Wind SE',
#        'Moderate Wind SW', 'Moderate Wind NW', 'High Wind NE', 'High Wind SE',
#        'High Wind SW', 'High Wind NW'],
#       dtype='object')

# %%
ytrain=df[["Status"]]
ytrain.head()
# Out:
#   Status
# 0     HU
# 1     HU
# 2     HU
# 3     HU
# 4     HU

# %%
ytrain.columns
# Out:
# Index(['Status'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
df["Status"]=le.fit_transform(df["Status"])

# %%
df["Status"]
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 49100    1
# 49101    1
# 49102    1
# 49103    1
# 49104    1
# Name: Status, Length: 49105, dtype: int32

# %%
df["Status"].value_counts()
# Out:
# 7    17804
# 2    14537
# 6     9891
# 1     4798
# 3     1005
# 5      557
# 4      293
# 8      116
# 0      104
# Name: Status, dtype: int64

# %%
df.corr(method="pearson")
# Out:
#                       Date      Time    Status  Maximum Wind  \
# Date              1.000000  0.001195  0.059272     -0.220613
# Time              0.001195  1.000000 -0.004677     -0.005017
# Status            0.059272 -0.004677  1.000000     -0.524354
# Maximum Wind     -0.220613 -0.005017 -0.524354      1.000000
# Minimum Pressure  0.723695  0.022164 -0.040449      0.010246
# Low Wind NE       0.489625 -0.003209 -0.034705     -0.036039
# Low Wind SE       0.489646 -0.002986 -0.037054     -0.037226
# Low Wind SW       0.490028 -0.003384 -0.038578     -0.039726
# Low Wind NW       0.489972 -0.003364 -0.036013     -0.037769
# Moderate Wind NE  0.490979 -0.003282 -0.033448     -0.041661
# Moderate Wind SE  0.490990 -0.003275 -0.034031     -0.042496
# Moderate Wind SW  0.491214 -0.003326 -0.032957     -0.044822
# Moderate Wind NW  0.491101 -0.003324 -0.033163     -0.043316
# High Wind NE      0.491380 -0.003330 -0.031579     -0.046199
# ...

# %%
df.describe()
# Out:
#                Date          Time        Status  Maximum Wind  \
# count  4.910500e+04  49105.000000  49105.000000  49105.000000
# mean   1.949802e+07    910.125975      4.597210     52.005091
# std    4.461850e+05    671.043363      2.424731     27.681902
# min    1.851062e+07      0.000000      0.000000    -99.000000
# 25%    1.911110e+07    600.000000      2.000000     35.000000
# 50%    1.956093e+07   1200.000000      6.000000     45.000000
# 75%    1.989081e+07   1800.000000      7.000000     70.000000
# max    2.015111e+07   2330.000000      8.000000    165.000000
#
#        Minimum Pressure   Low Wind NE   Low Wind SE   Low Wind SW  \
# count      49105.000000  49105.000000  49105.000000  49105.000000
# mean        -251.406496   -868.671031   -869.315772   -872.676428
# std          964.313907    353.299666    351.548910    342.153768
# min         -999.000000   -999.000000   -999.000000   -999.000000
# 25%         -999.000000   -999.000000   -999.000000   -999.000000
# ...

# %%
df.min()
# Out:
# ID                             AL011851
# Name                                AMY
# Date                           18510625
# Time                                  0
# Event
# Status                                0
# Latitude                          10.0N
# Longitude                          0.0W
# Maximum Wind                        -99
# Minimum Pressure                   -999
# Low Wind NE                        -999
# Low Wind SE                        -999
# Low Wind SW                        -999
# Low Wind NW                        -999
# Moderate Wind NE                   -999
# Moderate Wind SE                   -999
# Moderate Wind SW                   -999
# Moderate Wind NW                   -999
# High Wind NE                       -999
# High Wind SE                       -999
# High Wind SW                       -999
# High Wind NW                       -999
# dtype: object

# %%
df.isnull().sum()
# Out:
# ID                  0
# Name                0
# Date                0
# Time                0
# Event               0
# Status              0
# Latitude            0
# Longitude           0
# Maximum Wind        0
# Minimum Pressure    0
# Low Wind NE         0
# Low Wind SE         0
# Low Wind SW         0
# Low Wind NW         0
# Moderate Wind NE    0
# Moderate Wind SE    0
# Moderate Wind SW    0
# Moderate Wind NW    0
# High Wind NE        0
# High Wind SE        0
# High Wind SW        0
# High Wind NW        0
# dtype: int64

# %%
dftest=pd.read_csv("pacifictest.csv")

# %%
dftest.columns
# Out:
# Index(['ID', 'Name', 'Date', 'Time', 'Event', 'Status', 'Latitude',
#        'Longitude', 'Maximum Wind', 'Minimum Pressure', 'Low Wind NE',
#        'Low Wind SE', 'Low Wind SW', 'Low Wind NW', 'Moderate Wind NE',
#        'Moderate Wind SE', 'Moderate Wind SW', 'Moderate Wind NW',
#        'High Wind NE', 'High Wind SE', 'High Wind SW', 'High Wind NW'],
#       dtype='object')

# %%
dftest["Status"]=le.fit_transform(dftest["Status"])

# %%
xtest=dftest[[c for c in dftest if c not in ["Status"]]]
xtest
# Out:
#              ID                 Name      Date  Time Event Latitude Longitude  \
# 0      EP011949              UNNAMED  19490611     0          20.2N    106.3W
# 1      EP011949              UNNAMED  19490611   600          20.2N    106.4W
# 2      EP011949              UNNAMED  19490611  1200          20.2N    106.7W
# 3      EP011949              UNNAMED  19490611  1800          20.3N    107.7W
# 4      EP011949              UNNAMED  19490612     0          20.4N    108.6W
# ...         ...                  ...       ...   ...   ...      ...       ...
# 26132  EP222015               SANDRA  20151128  1200          21.7N    109.0W
# 26133  EP222015               SANDRA  20151128  1800          22.4N    108.7W
# 26134  EP222015               SANDRA  20151129     0          23.1N    108.3W
# 26135  EP222015               SANDRA  20151129   600          23.5N    107.9W
# 26136  EP222015               SANDRA  20151129  1200          24.2N    107.7W
#
# ...

# %%
ytest=dftest[["Status"]]
ytest.head()
# Out:
#    Status
# 0      11
# 1      11
# 2      11
# 3      11
# 4      11

# %%
ytest.shape
# Out:
# (26137, 1)

# %%
dftest["Status"].value_counts()
# Out:
# 11    10076
# 10     6965
# 3      6765
# 5      1828
# 0       217
# 1       152
# 2       110
# 8         7
# 9         6
# 6         6
# 7         4
# 4         1
# Name: Status, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49105 entries, 0 to 49104
# Data columns (total 22 columns):
# ID                  49105 non-null object
# Name                49105 non-null object
# Date                49105 non-null int64
# Time                49105 non-null int64
# Event               49105 non-null object
# Status              49105 non-null int32
# Latitude            49105 non-null object
# Longitude           49105 non-null object
# Maximum Wind        49105 non-null int64
# Minimum Pressure    49105 non-null int64
# Low Wind NE         49105 non-null int64
# Low Wind SE         49105 non-null int64
# Low Wind SW         49105 non-null int64
# Low Wind NW         49105 non-null int64
# Moderate Wind NE    49105 non-null int64
# Moderate Wind SE    49105 non-null int64
# Moderate Wind SW    49105 non-null int64
# Moderate Wind NW    49105 non-null int64
# High Wind NE        49105 non-null int64
# High Wind SE        49105 non-null int64
# ...

# %%
xtrain.head()
# Out:
#          ID                 Name      Date  Time Event Latitude Longitude  \
# 0  AL011851              UNNAMED  18510625     0          28.0N     94.8W
# 1  AL011851              UNNAMED  18510625   600          28.0N     95.4W
# 2  AL011851              UNNAMED  18510625  1200          28.0N     96.0W
# 3  AL011851              UNNAMED  18510625  1800          28.1N     96.5W
# 4  AL011851              UNNAMED  18510625  2100     L    28.2N     96.8W
#
#    Maximum Wind  Minimum Pressure  Low Wind NE  ...  Low Wind SW  Low Wind NW  \
# 0            80              -999         -999  ...         -999         -999
# 1            80              -999         -999  ...         -999         -999
# 2            80              -999         -999  ...         -999         -999
# 3            80              -999         -999  ...         -999         -999
# 4            80              -999         -999  ...         -999         -999
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform(xtrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-92ef15187ecd> in <module>
#       1 from sklearn.preprocessing import LabelEncoder
#       2 le=LabelEncoder()
# ----> 3 le.fit_transform(xtrain)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     233         y : array-like of shape [n_samples]
#     234         """
# --> 235         y = column_or_1d(y, warn=True)
#     236         self.classes_, y = _encode(y, encode=True)
#     237         return y
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#     758         return np.ravel(y)
#     759
# --> 760     raise ValueError("bad input shape {0}".format(shape))
#     761
#     762
#
# ValueError: bad input shape (49105, 21)

# %%
xtrain
